# %% [markdown]
# # PIPENET 검진 프로그램
#
# 가이드 `PIPENET 결과물로 검증하는 방법 V4(26.4.08)` 기준으로 결과표(`docx` 또는 `pdf`)와 모델 파일(`sdf`)을 검증한다.

# %%
from pathlib import Path

from pipenet_validator import PipenetGuideValidator

# %%
WORK_DIR = Path(r"C:/Users/admin/Desktop/작업")

report_path = next(WORK_DIR.glob("*.docx"))
sdf_path = next(WORK_DIR.glob("*.sdf"))

validator = PipenetGuideValidator(report_path=report_path, sdf_path=sdf_path)
validation = validator.validate()

validation["summary"]

# %%
validation["stats"]

# %%
print(validation["report"])
